# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

nba_data_to_load = "Resources/NBA Stats 2009-19.xlsx"
nba_data_09_10_df = pd.read_excel(nba_data_to_load, "2009-10")
nba_data_10_11_df = pd.read_excel(nba_data_to_load, "2010-11")
nba_data_11_12_df = pd.read_excel(nba_data_to_load, "2011-12")
nba_data_12_13_df = pd.read_excel(nba_data_to_load, "2012-13")
nba_data_13_14_df = pd.read_excel(nba_data_to_load, "2013-14")
nba_data_14_15_df = pd.read_excel(nba_data_to_load, "2014-15")
nba_data_15_16_df = pd.read_excel(nba_data_to_load, "2015-16")
nba_data_16_17_df = pd.read_excel(nba_data_to_load, "2016-17")
nba_data_17_18_df = pd.read_excel(nba_data_to_load, "2017-18")
nba_data_18_19_df = pd.read_excel(nba_data_to_load, "2018-19")
nba_data_df = pd.concat([nba_data_09_10_df,nba_data_10_11_df,nba_data_11_12_df,nba_data_12_13_df,nba_data_13_14_df,nba_data_14_15_df,nba_data_15_16_df,nba_data_16_17_df,nba_data_17_18_df,nba_data_18_19_df])
nba_data_df
# Out:
#                       TEAM   Season  GP   W   L   WIN%   MIN    PTS   FGM  \
# 0            Atlanta Hawks  2009-10  82  53  29  0.646  48.4  101.7  38.8
# 1           Boston Celtics  2009-10  82  50  32  0.610  48.2   99.2  37.1
# 2        Charlotte Bobcats  2009-10  82  44  38  0.537  48.5   95.3  34.9
# 3            Chicago Bulls  2009-10  82  41  41  0.500  48.5   97.5  37.6
# 4      Cleveland Cavaliers  2009-10  82  61  21  0.744  48.2  102.1  37.8
# 5         Dallas Mavericks  2009-10  82  55  27  0.671  48.5  102.0  38.3
# 6           Denver Nuggets  2009-10  82  53  29  0.646  48.2  106.5  38.1
# 7          Detroit Pistons  2009-10  82  27  55  0.329  48.2   94.0  35.9
# 8    Golden State Warriors  2009-10  82  26  56  0.317  48.1  108.8  40.6
# 9          Houston Rockets  2009-10  82  42  40  0.512  48.5  102.4  37.7
# 10          Indiana Pacers  2009-10  82  32  50  0.390  48.1  100.8  36.8
# 11    Los Angeles Clippers  2009-10  82  29  53  0.354  48.1   95.7  36.6
# ...

# %%
nba_data_ready_df = nba_data_df[["TEAM","Season","WIN%", "PTS", "FGM", "FGA", "3PM", "3PA", "FTM", "FTA"]]
nba_data_ready_df
# Out:
#                       TEAM   Season   WIN%    PTS   FGM   FGA   3PM   3PA  \
# 0            Atlanta Hawks  2009-10  0.646  101.7  38.8  82.9   6.4  17.7
# 1           Boston Celtics  2009-10  0.610   99.2  37.1  76.8   6.1  17.5
# 2        Charlotte Bobcats  2009-10  0.537   95.3  34.9  76.9   5.6  16.2
# 3            Chicago Bulls  2009-10  0.500   97.5  37.6  83.2   4.3  13.0
# 4      Cleveland Cavaliers  2009-10  0.744  102.1  37.8  77.9   7.3  19.3
# 5         Dallas Mavericks  2009-10  0.671  102.0  38.3  82.4   6.8  18.3
# 6           Denver Nuggets  2009-10  0.646  106.5  38.1  81.4   6.6  18.5
# 7          Detroit Pistons  2009-10  0.329   94.0  35.9  80.5   4.6  14.5
# 8    Golden State Warriors  2009-10  0.317  108.8  40.6  86.5   7.7  20.6
# 9          Houston Rockets  2009-10  0.512  102.4  37.7  84.4   7.9  22.4
# 10          Indiana Pacers  2009-10  0.390  100.8  36.8  83.2   8.0  23.1
# 11    Los Angeles Clippers  2009-10  0.354   95.7  36.6  80.5   5.9  17.8
# ...

# %%
nba_data_ready_df = nba_data_df[["TEAM","Season","WIN%", "PTS", "FGM", "FGA", "3PM", "3PA", "FTM", "FTA"]]
nba_data_ready_df
# Out:
#                       TEAM   Season   WIN%    PTS   FGM   FGA   3PM   3PA  \
# 0            Atlanta Hawks  2009-10  0.646  101.7  38.8  82.9   6.4  17.7
# 1           Boston Celtics  2009-10  0.610   99.2  37.1  76.8   6.1  17.5
# 2        Charlotte Bobcats  2009-10  0.537   95.3  34.9  76.9   5.6  16.2
# 3            Chicago Bulls  2009-10  0.500   97.5  37.6  83.2   4.3  13.0
# 4      Cleveland Cavaliers  2009-10  0.744  102.1  37.8  77.9   7.3  19.3
# 5         Dallas Mavericks  2009-10  0.671  102.0  38.3  82.4   6.8  18.3
# 6           Denver Nuggets  2009-10  0.646  106.5  38.1  81.4   6.6  18.5
# 7          Detroit Pistons  2009-10  0.329   94.0  35.9  80.5   4.6  14.5
# 8    Golden State Warriors  2009-10  0.317  108.8  40.6  86.5   7.7  20.6
# 9          Houston Rockets  2009-10  0.512  102.4  37.7  84.4   7.9  22.4
# 10          Indiana Pacers  2009-10  0.390  100.8  36.8  83.2   8.0  23.1
# 11    Los Angeles Clippers  2009-10  0.354   95.7  36.6  80.5   5.9  17.8
# ...

# %%
#Golden State Warriors Total 3 Pointers
df = nba_data_ready_df.set_index("TEAM")
df.head(300)

warriors_seasons_ready = df.loc["Golden State Warriors"]
warriors_seasons_ready
# Out:
#                         Season   WIN%    PTS   FGM   FGA   3PM   3PA   FTM  \
# TEAM
# Golden State Warriors  2009-10  0.317  108.8  40.6  86.5   7.7  20.6  19.9
# Golden State Warriors  2010-11  0.439  103.4  39.6  85.9   8.4  21.3  15.7
# Golden State Warriors  2011-12  0.348   97.8  37.7  82.5   7.9  20.5  14.4
# Golden State Warriors  2012-13  0.573  101.2  38.2  83.4   8.0  19.9  16.8
# Golden State Warriors  2013-14  0.622  104.3  39.5  85.4   9.4  24.8  15.9
# Golden State Warriors  2014-15  0.817  110.0  41.6  87.0  10.8  27.0  16.0
# Golden State Warriors  2015-16  0.890  114.9  42.5  87.3  13.1  31.6  16.7
# Golden State Warriors  2016-17  0.817  115.9  43.1  87.1  12.0  31.2  17.8
# Golden State Warriors  2017-18  0.707  113.5  42.8  85.1  11.3  28.9  16.6
# Golden State Warriors  2018-19  0.695  117.7  44.0  89.8  13.3  34.4  16.3
#
#                         FTA
# TEAM
# Golden State Warriors  25.4
# Golden State Warriors  20.7
# Golden State Warriors  18.7
# ...

# %%
#Golden State Warriors Total 3 Pointers Attempted
total_three_pointers = warriors_seasons_ready['3PM'].sum()
#total_three_pointers

total_three_pointers_attempted = warriors_seasons_ready['3PA'].sum()
#total_three_pointers_attempted

total_three_pointers_attempted_percent = (total_three_pointers/total_three_pointers_attempted)*100
total_three_pointers_attempted_percent
# Out:
# 39.162182936202925

# %%
#nba_data_09_10_df = bottom_five_200910_df[["TEAM","Season","WIN%", "PTS", "FGM", "FGA", "3PM", "3PA", "FTM", "FTA"]]
#nba_data_09_10_df_sorted = nba_data_09_10_df.sort_values(["PTS"])

# %%
nba_data_10_11_df
# Out:
#                       TEAM   Season  GP   W   L   WIN%   MIN    PTS   FGM  \
# 0            Atlanta Hawks  2010-11  82  44  38  0.537  48.1   95.0  36.2
# 1           Boston Celtics  2010-11  82  56  26  0.683  48.2   96.5  36.9
# 2        Charlotte Bobcats  2010-11  82  34  48  0.415  48.3   93.3  35.0
# 3            Chicago Bulls  2010-11  82  62  20  0.756  48.4   98.6  37.1
# 4      Cleveland Cavaliers  2010-11  82  19  63  0.232  48.2   95.5  35.2
# 5         Dallas Mavericks  2010-11  82  57  25  0.695  48.1  100.2  37.4
# 6           Denver Nuggets  2010-11  82  50  32  0.610  48.1  107.5  38.4
# 7          Detroit Pistons  2010-11  82  30  52  0.366  48.5   97.0  37.3
# 8    Golden State Warriors  2010-11  82  36  46  0.439  48.4  103.4  39.6
# 9          Houston Rockets  2010-11  82  43  39  0.524  48.5  105.9  38.7
# 10          Indiana Pacers  2010-11  82  37  45  0.451  48.2   99.8  36.6
# 11    Los Angeles Clippers  2010-11  82  32  50  0.390  48.4   98.6  36.8
# ...

# %%
#Bottom 5 Teams Each Year Total 3 Pointers

# %%
nba_data_09_10_df
# Out:
#                       TEAM   Season  GP   W   L   WIN%   MIN    PTS   FGM  \
# 0            Atlanta Hawks  2009-10  82  53  29  0.646  48.4  101.7  38.8
# 1           Boston Celtics  2009-10  82  50  32  0.610  48.2   99.2  37.1
# 2        Charlotte Bobcats  2009-10  82  44  38  0.537  48.5   95.3  34.9
# 3            Chicago Bulls  2009-10  82  41  41  0.500  48.5   97.5  37.6
# 4      Cleveland Cavaliers  2009-10  82  61  21  0.744  48.2  102.1  37.8
# 5         Dallas Mavericks  2009-10  82  55  27  0.671  48.5  102.0  38.3
# 6           Denver Nuggets  2009-10  82  53  29  0.646  48.2  106.5  38.1
# 7          Detroit Pistons  2009-10  82  27  55  0.329  48.2   94.0  35.9
# 8    Golden State Warriors  2009-10  82  26  56  0.317  48.1  108.8  40.6
# 9          Houston Rockets  2009-10  82  42  40  0.512  48.5  102.4  37.7
# 10          Indiana Pacers  2009-10  82  32  50  0.390  48.1  100.8  36.8
# 11    Los Angeles Clippers  2009-10  82  29  53  0.354  48.1   95.7  36.6
# ...

# %%
nba_09_10_df = nba_data_09_10_df[["TEAM","Season","WIN%", "PTS", "FGM", "FGA", "3PM", "3PA", "FTM", "FTA"]]
nba_09_10_df

nba_09_10_df_formatted = nba_09_10_df.sort_values(["WIN%"], ascending=False).head(29)
nba_09_10_df_formatted
# Out:
#                       TEAM   Season   WIN%    PTS   FGM   FGA   3PM   3PA  \
# 4      Cleveland Cavaliers  2009-10  0.744  102.1  37.8  77.9   7.3  19.3
# 21           Orlando Magic  2009-10  0.720  102.8  36.6  78.0  10.3  27.3
# 12      Los Angeles Lakers  2009-10  0.695  101.7  38.3  83.8   6.5  19.0
# 5         Dallas Mavericks  2009-10  0.671  102.0  38.3  82.4   6.8  18.3
# 23            Phoenix Suns  2009-10  0.659  110.2  40.7  82.8   8.9  21.6
# 0            Atlanta Hawks  2009-10  0.646  101.7  38.8  82.9   6.4  17.7
# 28               Utah Jazz  2009-10  0.646  104.2  39.4  80.2   5.4  14.7
# 6           Denver Nuggets  2009-10  0.646  106.5  38.1  81.4   6.6  18.5
# 26       San Antonio Spurs  2009-10  0.610  101.4  38.4  81.2   6.8  18.9
# 24  Portland Trail Blazers  2009-10  0.610   98.1  36.3  78.7   6.0  16.9
# 20   Oklahoma City Thunder  2009-10  0.610  101.5  37.4  80.8   5.1  15.0
# 1           Boston Celtics  2009-10  0.610   99.2  37.1  76.8   6.1  17.5
# ...

# %%
top_team_09_10 = nba_09_10_df_formatted.head(1)
top_team_09_10
# Out:
#                   TEAM   Season   WIN%    PTS   FGM   FGA  3PM   3PA   FTM  \
# 4  Cleveland Cavaliers  2009-10  0.744  102.1  37.8  77.9  7.3  19.3  19.1
#
#     FTA
# 4  26.6

# %%
bottom_five_teams_09_10 = nba_09_10_df_formatted.tail(5)
bottom_five_teams_09_10
# Out:
#                       TEAM   Season   WIN%    PTS   FGM   FGA  3PM   3PA  \
# 7          Detroit Pistons  2009-10  0.329   94.0  35.9  80.5  4.6  14.5
# 8    Golden State Warriors  2009-10  0.317  108.8  40.6  86.5  7.7  20.6
# 29      Washington Wizards  2009-10  0.317   96.2  36.7  81.7  5.3  14.9
# 25        Sacramento Kings  2009-10  0.305  100.0  38.3  84.1  5.9  16.9
# 16  Minnesota Timberwolves  2009-10  0.183   98.2  37.9  84.4  4.9  14.4
#
#      FTM   FTA
# 7   17.7  24.4
# 8   19.9  25.4
# 29  17.6  23.1
# 25  17.4  24.0
# 16  17.5  23.5

# %%
nba_09_10_total = pd.concat([top_team_09_10,bottom_five_teams_09_10])
nba_09_10_total
# Out:
#                       TEAM   Season   WIN%    PTS   FGM   FGA  3PM   3PA  \
# 4      Cleveland Cavaliers  2009-10  0.744  102.1  37.8  77.9  7.3  19.3
# 7          Detroit Pistons  2009-10  0.329   94.0  35.9  80.5  4.6  14.5
# 8    Golden State Warriors  2009-10  0.317  108.8  40.6  86.5  7.7  20.6
# 29      Washington Wizards  2009-10  0.317   96.2  36.7  81.7  5.3  14.9
# 25        Sacramento Kings  2009-10  0.305  100.0  38.3  84.1  5.9  16.9
# 16  Minnesota Timberwolves  2009-10  0.183   98.2  37.9  84.4  4.9  14.4
#
#      FTM   FTA
# 4   19.1  26.6
# 7   17.7  24.4
# 8   19.9  25.4
# 29  17.6  23.1
# 25  17.4  24.0
# 16  17.5  23.5

# %%
nba_10_11_df = nba_data_10_11_df[["TEAM","Season","WIN%", "PTS", "FGM", "FGA", "3PM", "3PA", "FTM", "FTA"]]
nba_10_11_df

nba_10_11_df_formatted = nba_10_11_df.sort_values(["WIN%"], ascending=False).head(29)
nba_10_11_df_formatted
# Out:
#                       TEAM   Season   WIN%    PTS   FGM   FGA  3PM   3PA  \
# 3            Chicago Bulls  2010-11  0.756   98.6  37.1  80.3  6.2  17.3
# 26       San Antonio Spurs  2010-11  0.744  103.7  38.4  80.8  8.4  21.1
# 14              Miami Heat  2010-11  0.707  102.1  37.0  76.8  6.7  18.0
# 5         Dallas Mavericks  2010-11  0.695  100.2  37.4  78.8  7.9  21.6
# 12      Los Angeles Lakers  2010-11  0.695  101.5  38.1  82.4  6.4  18.1
# 1           Boston Celtics  2010-11  0.683   96.5  36.9  75.8  5.0  13.6
# 20   Oklahoma City Thunder  2010-11  0.671  104.8  37.4  80.6  5.9  17.1
# 21           Orlando Magic  2010-11  0.634   99.2  36.0  78.2  9.4  25.6
# 6           Denver Nuggets  2010-11  0.610  107.5  38.4  80.6  8.1  20.8
# 24  Portland Trail Blazers  2010-11  0.585   96.3  36.0  80.5  6.3  18.3
# 18     New Orleans Hornets  2010-11  0.561   94.9  35.9  78.2  5.4  15.0
# 13       Memphis Grizzlies  2010-11  0.561   99.9  39.0  82.9  3.8  11.3
# ...

# %%
top_team_10_11 = nba_10_11_df_formatted.head(1)
top_team_10_11

bottom_five_teams_10_11 = nba_10_11_df_formatted.tail(5)
bottom_five_teams_10_11
# Out:
#                    TEAM   Season   WIN%   PTS   FGM   FGA  3PM   3PA   FTM  \
# 17      New Jersey Nets  2010-11  0.293  94.2  35.6  81.0  5.6  16.3  17.4
# 25     Sacramento Kings  2010-11  0.293  99.4  38.2  85.1  5.2  15.6  17.7
# 29   Washington Wizards  2010-11  0.280  97.3  37.2  84.0  4.8  14.4  18.2
# 27      Toronto Raptors  2010-11  0.268  99.1  38.3  82.4  4.2  13.3  18.2
# 4   Cleveland Cavaliers  2010-11  0.232  95.5  35.2  81.1  6.2  18.2  18.9
#
#      FTA
# 17  22.9
# 25  24.2
# 29  24.4
# 27  24.1
# 4   25.3

# %%
nba_10_11_total = pd.concat([top_team_10_11,bottom_five_teams_10_11])
nba_10_11_total
# Out:
#                    TEAM   Season   WIN%   PTS   FGM   FGA  3PM   3PA   FTM  \
# 3         Chicago Bulls  2010-11  0.756  98.6  37.1  80.3  6.2  17.3  18.2
# 17      New Jersey Nets  2010-11  0.293  94.2  35.6  81.0  5.6  16.3  17.4
# 25     Sacramento Kings  2010-11  0.293  99.4  38.2  85.1  5.2  15.6  17.7
# 29   Washington Wizards  2010-11  0.280  97.3  37.2  84.0  4.8  14.4  18.2
# 27      Toronto Raptors  2010-11  0.268  99.1  38.3  82.4  4.2  13.3  18.2
# 4   Cleveland Cavaliers  2010-11  0.232  95.5  35.2  81.1  6.2  18.2  18.9
#
#      FTA
# 3   24.5
# 17  22.9
# 25  24.2
# 29  24.4
# 27  24.1
# 4   25.3

# %%
nba_11_12_df = nba_data_11_12_df[["TEAM","Season","WIN%", "PTS", "FGM", "FGA", "3PM", "3PA", "FTM", "FTA"]]
nba_11_12_df

nba_11_12_df_formatted = nba_11_12_df.sort_values(["WIN%"], ascending=False).head(29)
nba_11_12_df_formatted
# Out:
#                       TEAM   Season   WIN%    PTS   FGM   FGA   3PM   3PA  \
# 3            Chicago Bulls  2011-12  0.758   96.3  37.4  82.8   6.3  16.9
# 26       San Antonio Spurs  2011-12  0.758  103.7  39.6  82.8   8.4  21.3
# 20   Oklahoma City Thunder  2011-12  0.712  103.1  37.3  79.2   7.2  20.0
# 14              Miami Heat  2011-12  0.697   98.5  37.1  79.0   5.6  15.6
# 10          Indiana Pacers  2011-12  0.636   97.7  35.7  81.4   5.9  16.1
# 13       Memphis Grizzlies  2011-12  0.621   95.0  36.7  82.2   4.2  12.9
# 12      Los Angeles Lakers  2011-12  0.621   97.3  36.8  80.6   5.5  16.8
# 11    Los Angeles Clippers  2011-12  0.606   97.5  37.0  81.3   7.8  21.8
# 0            Atlanta Hawks  2011-12  0.606   96.6  36.8  81.0   7.5  20.2
# 1           Boston Celtics  2011-12  0.591   91.8  35.5  77.1   5.5  15.0
# 6           Denver Nuggets  2011-12  0.576  104.1  39.0  81.9   6.6  19.9
# 21           Orlando Magic  2011-12  0.561   94.2  34.5  78.2  10.2  27.0
# ...

# %%
top_team_11_12 = nba_11_12_df_formatted.head(1)
top_team_11_12
# Out:
#             TEAM   Season   WIN%   PTS   FGM   FGA  3PM   3PA   FTM   FTA
# 3  Chicago Bulls  2011-12  0.758  96.3  37.4  82.8  6.3  16.9  15.2  21.1

# %%
bottom_five_teams_11_12 = nba_11_12_df_formatted.tail(5)
bottom_five_teams_11_12
# Out:
#                    TEAM   Season   WIN%   PTS   FGM   FGA  3PM   3PA   FTM  \
# 17      New Jersey Nets  2011-12  0.333  93.1  34.3  80.6  7.7  22.4  16.9
# 25     Sacramento Kings  2011-12  0.333  98.8  37.7  86.5  6.2  19.7  17.1
# 18  New Orleans Hornets  2011-12  0.318  89.6  34.8  77.3  3.9  11.8  16.0
# 4   Cleveland Cavaliers  2011-12  0.318  93.0  34.3  81.2  6.7  19.3  17.8
# 29   Washington Wizards  2011-12  0.303  93.6  36.6  83.0  5.2  16.3  15.3
#
#      FTA
# 17  21.7
# 25  23.2
# 18  21.2
# 4   24.9
# 29  21.0

# %%
nba_11_12_total = pd.concat([top_team_11_12,bottom_five_teams_11_12])
nba_11_12_total
# Out:
#                    TEAM   Season   WIN%   PTS   FGM   FGA  3PM   3PA   FTM  \
# 3         Chicago Bulls  2011-12  0.758  96.3  37.4  82.8  6.3  16.9  15.2
# 17      New Jersey Nets  2011-12  0.333  93.1  34.3  80.6  7.7  22.4  16.9
# 25     Sacramento Kings  2011-12  0.333  98.8  37.7  86.5  6.2  19.7  17.1
# 18  New Orleans Hornets  2011-12  0.318  89.6  34.8  77.3  3.9  11.8  16.0
# 4   Cleveland Cavaliers  2011-12  0.318  93.0  34.3  81.2  6.7  19.3  17.8
# 29   Washington Wizards  2011-12  0.303  93.6  36.6  83.0  5.2  16.3  15.3
#
#      FTA
# 3   21.1
# 17  21.7
# 25  23.2
# 18  21.2
# 4   24.9
# 29  21.0

# %%
nba_12_13_df = nba_data_12_13_df[["TEAM","Season","WIN%", "PTS", "FGM", "FGA", "3PM", "3PA", "FTM", "FTA"]]
nba_12_13_df

nba_12_13_df_formatted = nba_12_13_df.sort_values(["WIN%"], ascending=False).head(29)
nba_12_13_df_formatted
# Out:
#                       TEAM   Season   WIN%    PTS   FGM   FGA   3PM   3PA  \
# 13              Miami Heat  2012-13  0.805  102.9  38.4  77.4   8.7  22.1
# 18   Oklahoma City Thunder  2012-13  0.732  105.7  38.1  79.3   7.3  19.4
# 24       San Antonio Spurs  2012-13  0.707  103.0  39.1  81.4   8.1  21.5
# 6           Denver Nuggets  2012-13  0.695  106.1  40.7  85.2   6.4  18.5
# 10    Los Angeles Clippers  2012-13  0.683  101.1  38.5  80.6   7.6  21.4
# 12       Memphis Grizzlies  2012-13  0.683   93.4  36.1  81.5   4.7  13.5
# 17         New York Knicks  2012-13  0.659  100.0  36.5  81.6  10.9  28.9
# 29          Indiana Pacers  2012-13  0.605   94.7  35.1  80.6   6.9  19.7
# 1            Brooklyn Nets  2012-13  0.598   96.9  35.9  79.8   7.7  21.5
# 8    Golden State Warriors  2012-13  0.573  101.2  38.2  83.4   8.0  19.9
# 3            Chicago Bulls  2012-13  0.549   93.2  35.7  81.7   5.4  15.4
# 9          Houston Rockets  2012-13  0.549  106.0  38.1  82.7  10.6  28.9
# ...

# %%
top_team_12_13 = nba_12_13_df_formatted.head(1)
top_team_12_13
# Out:
#           TEAM   Season   WIN%    PTS   FGM   FGA  3PM   3PA   FTM   FTA
# 13  Miami Heat  2012-13  0.805  102.9  38.4  77.4  8.7  22.1  17.4  23.0

# %%
bottom_five_teams_12_13 = nba_12_13_df_formatted.tail(5)
bottom_five_teams_12_13
# Out:
#                    TEAM   Season   WIN%    PTS   FGM   FGA  3PM   3PA   FTM  \
# 23     Sacramento Kings  2012-13  0.341  100.2  37.6  84.2  7.4  20.5  17.5
# 16  New Orleans Hornets  2012-13  0.329   94.1  36.0  80.4  6.5  18.0  15.5
# 21         Phoenix Suns  2012-13  0.305   95.2  37.3  84.4  5.9  17.7  14.7
# 4   Cleveland Cavaliers  2012-13  0.293   96.5  36.5  84.2  6.7  19.3  16.8
# 2     Charlotte Bobcats  2012-13  0.256   93.4  34.4  81.1  5.7  17.1  18.9
#
#      FTA
# 23  22.8
# 16  20.0
# 21  19.7
# 4   22.3
# 2   25.1

# %%
nba_12_13_total = pd.concat([top_team_12_13,bottom_five_teams_12_13])
nba_12_13_total
# Out:
#                    TEAM   Season   WIN%    PTS   FGM   FGA  3PM   3PA   FTM  \
# 13           Miami Heat  2012-13  0.805  102.9  38.4  77.4  8.7  22.1  17.4
# 23     Sacramento Kings  2012-13  0.341  100.2  37.6  84.2  7.4  20.5  17.5
# 16  New Orleans Hornets  2012-13  0.329   94.1  36.0  80.4  6.5  18.0  15.5
# 21         Phoenix Suns  2012-13  0.305   95.2  37.3  84.4  5.9  17.7  14.7
# 4   Cleveland Cavaliers  2012-13  0.293   96.5  36.5  84.2  6.7  19.3  16.8
# 2     Charlotte Bobcats  2012-13  0.256   93.4  34.4  81.1  5.7  17.1  18.9
#
#      FTA
# 13  23.0
# 23  22.8
# 16  20.0
# 21  19.7
# 4   22.3
# 2   25.1

# %%
nba_13_14_df = nba_data_13_14_df[["TEAM","Season","WIN%", "PTS", "FGM", "FGA", "3PM", "3PA", "FTM", "FTA"]]
nba_13_14_df

nba_13_14_df_formatted = nba_13_14_df.sort_values(["WIN%"], ascending=False).head(29)
nba_13_14_df_formatted
# Out:
#                       TEAM   Season   WIN%    PTS   FGM   FGA  3PM   3PA  \
# 26       San Antonio Spurs  2013-14  0.756  105.4  40.6  83.5  8.5  21.4
# 20   Oklahoma City Thunder  2013-14  0.720  106.2  39.0  82.7  8.1  22.4
# 12    Los Angeles Clippers  2013-14  0.695  107.9  39.1  82.5  8.5  24.0
# 11          Indiana Pacers  2013-14  0.683   96.7  36.0  80.2  6.7  18.8
# 15              Miami Heat  2013-14  0.659  102.2  38.3  76.5  8.1  22.3
# 24  Portland Trail Blazers  2013-14  0.659  106.7  39.1  87.0  9.4  25.3
# 10         Houston Rockets  2013-14  0.659  107.7  38.0  80.5  9.5  26.6
# 9    Golden State Warriors  2013-14  0.622  104.3  39.5  85.4  9.4  24.8
# 14       Memphis Grizzlies  2013-14  0.610   96.1  38.1  82.0  4.9  14.0
# 6         Dallas Mavericks  2013-14  0.598  104.8  39.6  83.6  8.8  22.9
# 27         Toronto Raptors  2013-14  0.585  101.3  36.5  81.9  8.7  23.4
# 4            Chicago Bulls  2013-14  0.585   93.7  34.7  80.2  6.2  17.8
# ...

# %%
top_team_13_14 = nba_13_14_df_formatted.head(1)
top_team_13_14
# Out:
#                  TEAM   Season   WIN%    PTS   FGM   FGA  3PM   3PA   FTM  \
# 26  San Antonio Spurs  2013-14  0.756  105.4  40.6  83.5  8.5  21.4  15.7
#
#      FTA
# 26  20.0

# %%
bottom_five_teams_13_14 = nba_13_14_df_formatted.tail(5)
bottom_five_teams_13_14
# Out:
#                   TEAM   Season   WIN%    PTS   FGM   FGA  3PM   3PA   FTM  \
# 13  Los Angeles Lakers  2013-14  0.329  103.0  38.3  85.1  9.4  24.8  17.0
# 1       Boston Celtics  2013-14  0.305   96.2  36.5  83.9  7.0  21.1  16.2
# 28           Utah Jazz  2013-14  0.305   95.0  36.0  81.1  6.6  19.2  16.4
# 21       Orlando Magic  2013-14  0.280   96.5  36.9  82.7  6.9  19.5  15.9
# 22  Philadelphia 76ers  2013-14  0.232   99.5  37.9  87.2  7.0  22.5  16.6
#
#      FTA
# 13  22.4
# 1   20.8
# 28  22.0
# 21  20.9
# 22  23.4

# %%
nba_13_14_total = pd.concat([top_team_13_14,bottom_five_teams_13_14])
nba_13_14_total
# Out:
#                   TEAM   Season   WIN%    PTS   FGM   FGA  3PM   3PA   FTM  \
# 26   San Antonio Spurs  2013-14  0.756  105.4  40.6  83.5  8.5  21.4  15.7
# 13  Los Angeles Lakers  2013-14  0.329  103.0  38.3  85.1  9.4  24.8  17.0
# 1       Boston Celtics  2013-14  0.305   96.2  36.5  83.9  7.0  21.1  16.2
# 28           Utah Jazz  2013-14  0.305   95.0  36.0  81.1  6.6  19.2  16.4
# 21       Orlando Magic  2013-14  0.280   96.5  36.9  82.7  6.9  19.5  15.9
# 22  Philadelphia 76ers  2013-14  0.232   99.5  37.9  87.2  7.0  22.5  16.6
#
#      FTA
# 26  20.0
# 13  22.4
# 1   20.8
# 28  22.0
# 21  20.9
# 22  23.4

# %%
nba_14_15_df = nba_data_14_15_df[["TEAM","Season","WIN%", "PTS", "FGM", "FGA", "3PM", "3PA", "FTM", "FTA"]]
nba_14_15_df

nba_14_15_df_formatted = nba_14_15_df.sort_values(["WIN%"], ascending=False).head(29)
nba_14_15_df_formatted
# Out:
#                       TEAM   Season   WIN%    PTS   FGM   FGA   3PM   3PA  \
# 9    Golden State Warriors  2014-15  0.817  110.0  41.6  87.0  10.8  27.0
# 0            Atlanta Hawks  2014-15  0.732  102.5  38.1  81.7  10.0  26.2
# 12    Los Angeles Clippers  2014-15  0.683  106.7  39.4  83.3  10.1  26.9
# 10         Houston Rockets  2014-15  0.683  103.9  37.0  83.3  11.4  32.7
# 26       San Antonio Spurs  2014-15  0.671  103.2  39.1  83.6   8.3  22.5
# 14       Memphis Grizzlies  2014-15  0.671   98.3  37.8  82.5   5.2  15.2
# 5      Cleveland Cavaliers  2014-15  0.646  103.1  37.7  82.2  10.1  27.5
# 24  Portland Trail Blazers  2014-15  0.622  102.8  38.7  86.0   9.8  27.2
# 4            Chicago Bulls  2014-15  0.610  100.8  36.6  82.9   7.9  22.3
# 6         Dallas Mavericks  2014-15  0.610  105.2  39.7  85.8   8.9  25.4
# 27         Toronto Raptors  2014-15  0.598  104.0  37.9  83.3   8.9  25.1
# 29      Washington Wizards  2014-15  0.561   98.5  38.3  82.8   6.1  16.8
# ...

# %%
top_team_14_15 = nba_14_15_df_formatted.head(1)
top_team_14_15
# Out:
#                     TEAM   Season   WIN%    PTS   FGM   FGA   3PM   3PA   FTM  \
# 9  Golden State Warriors  2014-15  0.817  110.0  41.6  87.0  10.8  27.0  16.0
#
#     FTA
# 9  20.8

# %%
bottom_five_teams_14_15 = nba_14_15_df_formatted.tail(5)
bottom_five_teams_14_15
# Out:
#                   TEAM   Season   WIN%    PTS   FGM   FGA  3PM   3PA   FTM  \
# 25    Sacramento Kings  2014-15  0.354  101.3  36.7  80.7  5.6  16.5  22.3
# 21       Orlando Magic  2014-15  0.305   95.7  37.5  82.8  6.8  19.5  13.9
# 13  Los Angeles Lakers  2014-15  0.256   98.5  37.2  85.6  6.5  18.9  17.5
# 22  Philadelphia 76ers  2014-15  0.220   92.0  33.7  82.6  8.4  26.3  16.1
# 19     New York Knicks  2014-15  0.207   91.9  35.1  82.0  6.8  19.7  14.8
#
#      FTA
# 25  29.3
# 21  19.1
# 13  23.6
# 22  23.8
# 19  19.2

# %%
nba_14_15_total = pd.concat([top_team_14_15,bottom_five_teams_14_15])
nba_14_15_total
# Out:
#                      TEAM   Season   WIN%    PTS   FGM   FGA   3PM   3PA  \
# 9   Golden State Warriors  2014-15  0.817  110.0  41.6  87.0  10.8  27.0
# 25       Sacramento Kings  2014-15  0.354  101.3  36.7  80.7   5.6  16.5
# 21          Orlando Magic  2014-15  0.305   95.7  37.5  82.8   6.8  19.5
# 13     Los Angeles Lakers  2014-15  0.256   98.5  37.2  85.6   6.5  18.9
# 22     Philadelphia 76ers  2014-15  0.220   92.0  33.7  82.6   8.4  26.3
# 19        New York Knicks  2014-15  0.207   91.9  35.1  82.0   6.8  19.7
#
#      FTM   FTA
# 9   16.0  20.8
# 25  22.3  29.3
# 21  13.9  19.1
# 13  17.5  23.6
# 22  16.1  23.8
# 19  14.8  19.2

# %%
nba_15_16_df = nba_data_15_16_df[["TEAM","Season","WIN%", "PTS", "FGM", "FGA", "3PM", "3PA", "FTM", "FTA"]]
nba_15_16_df

nba_15_16_df_formatted = nba_15_16_df.sort_values(["WIN%"], ascending=False).head(29)
nba_15_16_df_formatted
# Out:
#                       TEAM   Season   WIN%    PTS   FGM   FGA   3PM   3PA  \
# 9    Golden State Warriors  2015-16  0.890  114.9  42.5  87.3  13.1  31.6
# 26       San Antonio Spurs  2015-16  0.817  103.5  40.1  82.9   7.0  18.5
# 5      Cleveland Cavaliers  2015-16  0.695  104.3  38.7  84.0  10.7  29.6
# 27         Toronto Raptors  2015-16  0.683  102.7  36.7  81.3   8.6  23.4
# 20   Oklahoma City Thunder  2015-16  0.671  110.2  41.1  86.4   8.3  23.7
# 12             LA Clippers  2015-16  0.646  104.5  38.3  82.4   9.7  26.7
# 0            Atlanta Hawks  2015-16  0.585  102.8  38.6  84.4   9.9  28.4
# 1           Boston Celtics  2015-16  0.585  105.7  39.2  89.2   8.7  26.1
# 15              Miami Heat  2015-16  0.585  100.0  38.4  81.7   6.1  18.0
# 3        Charlotte Hornets  2015-16  0.585  103.4  37.0  84.4  10.6  29.4
# 11          Indiana Pacers  2015-16  0.549  102.2  38.3  85.2   8.1  23.0
# 8          Detroit Pistons  2015-16  0.537  102.0  37.9  86.4   9.0  26.2
# ...

# %%
bottom_five_teams_15_16 = nba_15_16_df_formatted.tail(5)
bottom_five_teams_15_16
# Out:
#                       TEAM   Season   WIN%    PTS   FGM   FGA  3PM   3PA  \
# 18    New Orleans Pelicans  2015-16  0.366  102.7  38.5  85.9  8.6  23.8
# 17  Minnesota Timberwolves  2015-16  0.354  102.4  37.7  81.3  5.5  16.4
# 23            Phoenix Suns  2015-16  0.280  100.9  37.2  85.6  9.0  25.8
# 2            Brooklyn Nets  2015-16  0.256   98.6  38.2  84.4  6.5  18.4
# 13      Los Angeles Lakers  2015-16  0.207   97.3  35.1  84.8  7.8  24.6
#
#      FTM   FTA
# 18  17.3  22.2
# 17  21.4  27.0
# 23  17.5  23.2
# 2   15.7  20.7
# 13  19.3  24.7

# %%
top_team_15_16 = nba_15_16_df_formatted.head(1)
top_team_15_16
# Out:
#                     TEAM   Season  WIN%    PTS   FGM   FGA   3PM   3PA   FTM  \
# 9  Golden State Warriors  2015-16  0.89  114.9  42.5  87.3  13.1  31.6  16.7
#
#     FTA
# 9  21.8

# %%
nba_15_16_total = pd.concat([top_team_15_16,bottom_five_teams_15_16])
nba_15_16_total
# Out:
#                       TEAM   Season   WIN%    PTS   FGM   FGA   3PM   3PA  \
# 9    Golden State Warriors  2015-16  0.890  114.9  42.5  87.3  13.1  31.6
# 18    New Orleans Pelicans  2015-16  0.366  102.7  38.5  85.9   8.6  23.8
# 17  Minnesota Timberwolves  2015-16  0.354  102.4  37.7  81.3   5.5  16.4
# 23            Phoenix Suns  2015-16  0.280  100.9  37.2  85.6   9.0  25.8
# 2            Brooklyn Nets  2015-16  0.256   98.6  38.2  84.4   6.5  18.4
# 13      Los Angeles Lakers  2015-16  0.207   97.3  35.1  84.8   7.8  24.6
#
#      FTM   FTA
# 9   16.7  21.8
# 18  17.3  22.2
# 17  21.4  27.0
# 23  17.5  23.2
# 2   15.7  20.7
# 13  19.3  24.7

# %%
nba_16_17_df = nba_data_16_17_df[["TEAM","Season","WIN%", "PTS", "FGM", "FGA", "3PM", "3PA", "FTM", "FTA"]]
nba_16_17_df

nba_16_17_df_formatted = nba_16_17_df.sort_values(["WIN%"], ascending=False).head(29)
nba_16_17_df_formatted
# Out:
#                       TEAM   Season   WIN%    PTS   FGM   FGA   3PM   3PA  \
# 9    Golden State Warriors  2016-17  0.817  115.9  43.1  87.1  12.0  31.2
# 26       San Antonio Spurs  2016-17  0.744  105.3  39.3  83.7   9.2  23.5
# 10         Houston Rockets  2016-17  0.671  115.3  40.3  87.2  14.4  40.3
# 1           Boston Celtics  2016-17  0.646  108.0  38.6  85.1  12.0  33.4
# 12             LA Clippers  2016-17  0.622  108.7  39.5  83.2  10.3  27.4
# 28               Utah Jazz  2016-17  0.622  100.7  37.0  79.5   9.6  26.0
# 27         Toronto Raptors  2016-17  0.622  106.9  39.2  84.4   8.8  24.3
# 5      Cleveland Cavaliers  2016-17  0.622  110.3  39.9  84.9  13.0  33.9
# 29      Washington Wizards  2016-17  0.598  109.2  41.3  87.0   9.2  24.8
# 20   Oklahoma City Thunder  2016-17  0.573  106.6  39.5  87.4   8.4  25.8
# 14       Memphis Grizzlies  2016-17  0.524  100.5  36.4  83.6   9.4  26.5
# 0            Atlanta Hawks  2016-17  0.524  103.2  38.1  84.4   8.9  26.1
# ...

# %%
top_team_16_17 = nba_16_17_df_formatted.head(1)
top_team_16_17
# Out:
#                     TEAM   Season   WIN%    PTS   FGM   FGA   3PM   3PA   FTM  \
# 9  Golden State Warriors  2016-17  0.817  115.9  43.1  87.1  12.0  31.2  17.8
#
#     FTA
# 9  22.6

# %%
bottom_five_teams_16_17 = nba_16_17_df_formatted.tail(5)
bottom_five_teams_16_17
# Out:
#                   TEAM   Season   WIN%    PTS   FGM   FGA   3PM   3PA   FTM  \
# 19     New York Knicks  2016-17  0.378  104.3  39.6  88.5   8.6  24.7  16.6
# 21       Orlando Magic  2016-17  0.354  101.1  38.3  87.0   8.5  26.1  16.0
# 22  Philadelphia 76ers  2016-17  0.341  102.4  37.7  85.3  10.1  29.8  17.0
# 13  Los Angeles Lakers  2016-17  0.317  104.6  39.3  87.4   8.9  25.7  17.0
# 23        Phoenix Suns  2016-17  0.293  107.7  39.9  88.5   7.5  22.6  20.4
#
#      FTA
# 19  21.1
# 21  21.4
# 22  22.0
# 13  22.6
# 23  26.3

# %%
nba_16_17_total = pd.concat([top_team_16_17,bottom_five_teams_16_17])
nba_16_17_total
# Out:
#                      TEAM   Season   WIN%    PTS   FGM   FGA   3PM   3PA  \
# 9   Golden State Warriors  2016-17  0.817  115.9  43.1  87.1  12.0  31.2
# 19        New York Knicks  2016-17  0.378  104.3  39.6  88.5   8.6  24.7
# 21          Orlando Magic  2016-17  0.354  101.1  38.3  87.0   8.5  26.1
# 22     Philadelphia 76ers  2016-17  0.341  102.4  37.7  85.3  10.1  29.8
# 13     Los Angeles Lakers  2016-17  0.317  104.6  39.3  87.4   8.9  25.7
# 23           Phoenix Suns  2016-17  0.293  107.7  39.9  88.5   7.5  22.6
#
#      FTM   FTA
# 9   17.8  22.6
# 19  16.6  21.1
# 21  16.0  21.4
# 22  17.0  22.0
# 13  17.0  22.6
# 23  20.4  26.3

# %%
nba_17_18_df = nba_data_17_18_df[["TEAM","Season","WIN%", "PTS", "FGM", "FGA", "3PM", "3PA", "FTM", "FTA"]]
nba_17_18_df

nba_17_18_df_formatted = nba_17_18_df.sort_values(["WIN%"], ascending=False).head(29)
nba_17_18_df_formatted
# Out:
#                       TEAM   Season   WIN%    PTS   FGM   FGA   3PM   3PA  \
# 10         Houston Rockets  2017-18  0.793  112.4  38.7  84.2  15.3  42.3
# 27         Toronto Raptors  2017-18  0.720  111.7  41.3  87.4  11.8  33.0
# 9    Golden State Warriors  2017-18  0.707  113.5  42.8  85.1  11.3  28.9
# 1           Boston Celtics  2017-18  0.671  104.0  38.3  85.1  11.5  30.4
# 22      Philadelphia 76ers  2017-18  0.634  109.8  40.8  86.6  11.0  29.8
# 5      Cleveland Cavaliers  2017-18  0.610  110.9  40.4  84.8  12.0  32.1
# 24  Portland Trail Blazers  2017-18  0.598  105.6  39.3  87.0  10.3  28.1
# 28               Utah Jazz  2017-18  0.585  104.1  38.3  82.9  10.8  29.6
# 11          Indiana Pacers  2017-18  0.585  105.6  40.8  86.4   9.0  24.5
# 20   Oklahoma City Thunder  2017-18  0.585  107.9  39.9  88.1  10.7  30.4
# 18    New Orleans Pelicans  2017-18  0.585  111.7  42.7  88.3  10.2  28.2
# 26       San Antonio Spurs  2017-18  0.573  102.7  39.0  85.4   8.5  24.1
# ...

# %%
top_team_17_18 = nba_17_18_df_formatted.head(1)
top_team_17_18
# Out:
#                TEAM   Season   WIN%    PTS   FGM   FGA   3PM   3PA   FTM   FTA
# 10  Houston Rockets  2017-18  0.793  112.4  38.7  84.2  15.3  42.3  19.6  25.1

# %%
bottom_five_teams_17_18 = nba_17_18_df_formatted.tail(5)
bottom_five_teams_17_18
# Out:
#                  TEAM   Season   WIN%    PTS   FGM   FGA   3PM   3PA   FTM  \
# 4       Chicago Bulls  2017-18  0.329  102.9  38.7  88.8  11.0  31.1  14.6
# 21      Orlando Magic  2017-18  0.305  103.4  38.8  85.9  10.3  29.3  15.5
# 6    Dallas Mavericks  2017-18  0.293  102.3  38.1  85.9  11.8  32.8  14.2
# 0       Atlanta Hawks  2017-18  0.293  103.4  38.2  85.5  11.2  31.0  15.8
# 14  Memphis Grizzlies  2017-18  0.268   99.3  36.7  82.8   9.2  26.2  16.6
#
#      FTA
# 4   19.2
# 21  20.5
# 6   18.7
# 0   20.2
# 14  21.1

# %%
nba_17_18_total = pd.concat([top_team_17_18,bottom_five_teams_17_18])
nba_17_18_total
# Out:
#                  TEAM   Season   WIN%    PTS   FGM   FGA   3PM   3PA   FTM  \
# 10    Houston Rockets  2017-18  0.793  112.4  38.7  84.2  15.3  42.3  19.6
# 4       Chicago Bulls  2017-18  0.329  102.9  38.7  88.8  11.0  31.1  14.6
# 21      Orlando Magic  2017-18  0.305  103.4  38.8  85.9  10.3  29.3  15.5
# 6    Dallas Mavericks  2017-18  0.293  102.3  38.1  85.9  11.8  32.8  14.2
# 0       Atlanta Hawks  2017-18  0.293  103.4  38.2  85.5  11.2  31.0  15.8
# 14  Memphis Grizzlies  2017-18  0.268   99.3  36.7  82.8   9.2  26.2  16.6
#
#      FTA
# 10  25.1
# 4   19.2
# 21  20.5
# 6   18.7
# 0   20.2
# 14  21.1

# %%
nba_18_19_df = nba_data_18_19_df[["TEAM","Season","WIN%", "PTS", "FGM", "FGA", "3PM", "3PA", "FTM", "FTA"]]
nba_18_19_df

nba_18_19_df_formatted = nba_18_19_df.sort_values(["WIN%"], ascending=False).head(29)
nba_18_19_df_formatted
# Out:
#                       TEAM   Season   WIN%    PTS   FGM   FGA   3PM   3PA  \
# 16         Milwaukee Bucks  2018-19  0.732  118.1  43.4  91.1  13.5  38.2
# 27         Toronto Raptors  2018-19  0.707  114.4  42.2  89.1  12.4  33.8
# 9    Golden State Warriors  2018-19  0.695  117.7  44.0  89.8  13.3  34.4
# 7           Denver Nuggets  2018-19  0.659  110.7  41.9  90.0  11.0  31.4
# 10         Houston Rockets  2018-19  0.646  113.9  39.2  87.4  16.1  45.4
# 24  Portland Trail Blazers  2018-19  0.646  114.7  42.3  90.6  11.0  30.7
# 22      Philadelphia 76ers  2018-19  0.622  115.2  41.5  88.2  10.8  30.2
# 28               Utah Jazz  2018-19  0.610  111.7  40.4  86.4  12.1  34.0
# 20   Oklahoma City Thunder  2018-19  0.598  114.5  42.6  94.0  11.4  32.6
# 1           Boston Celtics  2018-19  0.598  112.4  42.1  90.5  12.6  34.5
# 12             LA Clippers  2018-19  0.585  115.1  41.3  87.5  10.0  25.8
# 11          Indiana Pacers  2018-19  0.585  108.0  41.3  87.0   9.5  25.4
# ...

# %%
top_team_18_19 = nba_18_19_df_formatted.head(1)
top_team_18_19
# Out:
#                TEAM   Season   WIN%    PTS   FGM   FGA   3PM   3PA   FTM   FTA
# 16  Milwaukee Bucks  2018-19  0.732  118.1  43.4  91.1  13.5  38.2  17.9  23.2

# %%
bottom_five_teams_18_19 = nba_18_19_df_formatted.tail(5)
bottom_five_teams_18_19
# Out:
#                    TEAM   Season   WIN%    PTS   FGM   FGA   3PM   3PA   FTM  \
# 29   Washington Wizards  2018-19  0.390  114.0  42.1  90.1  11.3  33.3  18.4
# 0         Atlanta Hawks  2018-19  0.354  113.3  41.4  91.8  13.0  37.0  17.6
# 4         Chicago Bulls  2018-19  0.268  104.9  39.8  87.9   9.1  25.9  16.2
# 23         Phoenix Suns  2018-19  0.232  107.5  40.1  87.4   9.6  29.3  17.6
# 5   Cleveland Cavaliers  2018-19  0.232  104.5  38.9  87.6  10.3  29.1  16.4
#
#      FTA
# 29  23.9
# 0   23.4
# 4   20.7
# 23  22.7
# 5   20.7

# %%
nba_18_19_total = pd.concat([top_team_18_19,bottom_five_teams_18_19])
nba_18_19_total
# Out:
#                    TEAM   Season   WIN%    PTS   FGM   FGA   3PM   3PA   FTM  \
# 16      Milwaukee Bucks  2018-19  0.732  118.1  43.4  91.1  13.5  38.2  17.9
# 29   Washington Wizards  2018-19  0.390  114.0  42.1  90.1  11.3  33.3  18.4
# 0         Atlanta Hawks  2018-19  0.354  113.3  41.4  91.8  13.0  37.0  17.6
# 4         Chicago Bulls  2018-19  0.268  104.9  39.8  87.9   9.1  25.9  16.2
# 23         Phoenix Suns  2018-19  0.232  107.5  40.1  87.4   9.6  29.3  17.6
# 5   Cleveland Cavaliers  2018-19  0.232  104.5  38.9  87.6  10.3  29.1  16.4
#
#      FTA
# 16  23.2
# 29  23.9
# 0   23.4
# 4   20.7
# 23  22.7
# 5   20.7

# %%
nba_top_five_09_19 = pd.concat([top_team_09_10,top_team_10_11,top_team_11_12,top_team_12_13,top_team_13_14,top_team_14_15,top_team_15_16,top_team_16_17,top_team_17_18,top_team_18_19])
nba_top_five_09_19
# Out:
#                      TEAM   Season   WIN%    PTS   FGM   FGA   3PM   3PA  \
# 4     Cleveland Cavaliers  2009-10  0.744  102.1  37.8  77.9   7.3  19.3
# 3           Chicago Bulls  2010-11  0.756   98.6  37.1  80.3   6.2  17.3
# 3           Chicago Bulls  2011-12  0.758   96.3  37.4  82.8   6.3  16.9
# 13             Miami Heat  2012-13  0.805  102.9  38.4  77.4   8.7  22.1
# 26      San Antonio Spurs  2013-14  0.756  105.4  40.6  83.5   8.5  21.4
# 9   Golden State Warriors  2014-15  0.817  110.0  41.6  87.0  10.8  27.0
# 9   Golden State Warriors  2015-16  0.890  114.9  42.5  87.3  13.1  31.6
# 9   Golden State Warriors  2016-17  0.817  115.9  43.1  87.1  12.0  31.2
# 10        Houston Rockets  2017-18  0.793  112.4  38.7  84.2  15.3  42.3
# 16        Milwaukee Bucks  2018-19  0.732  118.1  43.4  91.1  13.5  38.2
#
#      FTM   FTA
# 4   19.1  26.6
# 3   18.2  24.5
# 3   15.2  21.1
# 13  17.4  23.0
# 26  15.7  20.0
# 9   16.0  20.8
# 9   16.7  21.8
# 9   17.8  22.6
# 10  19.6  25.1
# ...

# %%
#Scatter Plot
nba_2009_10_season = plt.scatter(nba_09_10_total["WIN%"],nba_09_10_total["3PM"])
nba_2010_11_season = plt.scatter(nba_10_11_total["WIN%"],nba_10_11_total["3PM"])
nba_2011_12_season = plt.scatter(nba_11_12_total["WIN%"],nba_11_12_total["3PM"])
nba_2012_13_season = plt.scatter(nba_12_13_total["WIN%"],nba_12_13_total["3PM"])
nba_2013_14_season = plt.scatter(nba_13_14_total["WIN%"],nba_13_14_total["3PM"])
nba_2014_15_season = plt.scatter(nba_14_15_total["WIN%"],nba_14_15_total["3PM"])
nba_2015_16_season = plt.scatter(nba_15_16_total["WIN%"],nba_15_16_total["3PM"])
nba_2016_17_season = plt.scatter(nba_16_17_total["WIN%"],nba_16_17_total["3PM"])
nba_2017_18_season = plt.scatter(nba_17_18_total["WIN%"],nba_17_18_total["3PM"])
nba_2018_19_season = plt.scatter(nba_18_19_total["WIN%"],nba_18_19_total["3PM"])

#Incorporate the other graph properties
plt.grid(True)
plt.title("Team 3 Point Shots")
plt.ylabel("Total 3 Pointers Made")
plt.xlabel("Win%")

#Create a legend
lgnd = plt.legend(fontsize="medium", mode="Expanded",
                 numpoints=1, scatterpoints=1,
                 loc="best", title="Shots By Season",
                 labelspacing=0.6,bbox_to_anchor=(1.2, -.27), 
                 fancybox=True, 
                 shadow=True, ncol=5)
lgnd.get_texts()[0].set_text('2009-10')
lgnd.get_texts()[1].set_text('2010-11')
lgnd.get_texts()[2].set_text('2011-12')
lgnd.get_texts()[3].set_text('2012-13')
lgnd.get_texts()[4].set_text('2013-14')
lgnd.get_texts()[5].set_text('2014-15')
lgnd.get_texts()[6].set_text('2015-16')
lgnd.get_texts()[7].set_text('2016-17')
lgnd.get_texts()[8].set_text('2017-18')
lgnd.get_texts()[9].set_text('2018-19')

lgnd.legendHandles[0]._sizes = [30]
lgnd.legendHandles[1]._sizes = [30]
lgnd.legendHandles[2]._sizes = [30]

# %%
nba_data_df = pd.concat([nba_data_09_10_df,nba_data_10_11_df,nba_data_11_12_df,nba_data_12_13_df,nba_data_13_14_df,nba_data_14_15_df,nba_data_15_16_df,nba_data_16_17_df,nba_data_17_18_df,nba_data_18_19_df])
nba_data_df
# Out:
#                       TEAM   Season  GP   W   L   WIN%   MIN    PTS   FGM  \
# 0            Atlanta Hawks  2009-10  82  53  29  0.646  48.4  101.7  38.8
# 1           Boston Celtics  2009-10  82  50  32  0.610  48.2   99.2  37.1
# 2        Charlotte Bobcats  2009-10  82  44  38  0.537  48.5   95.3  34.9
# 3            Chicago Bulls  2009-10  82  41  41  0.500  48.5   97.5  37.6
# 4      Cleveland Cavaliers  2009-10  82  61  21  0.744  48.2  102.1  37.8
# 5         Dallas Mavericks  2009-10  82  55  27  0.671  48.5  102.0  38.3
# 6           Denver Nuggets  2009-10  82  53  29  0.646  48.2  106.5  38.1
# 7          Detroit Pistons  2009-10  82  27  55  0.329  48.2   94.0  35.9
# 8    Golden State Warriors  2009-10  82  26  56  0.317  48.1  108.8  40.6
# 9          Houston Rockets  2009-10  82  42  40  0.512  48.5  102.4  37.7
# 10          Indiana Pacers  2009-10  82  32  50  0.390  48.1  100.8  36.8
# 11    Los Angeles Clippers  2009-10  82  29  53  0.354  48.1   95.7  36.6
# ...

# %%
#New Graph

# %%
top_teams_09_18 = pd.concat([top_team_09_10,top_team_10_11,top_team_11_12,top_team_12_13,top_team_13_14,top_team_14_15,top_team_15_16,top_team_16_17,top_team_17_18,top_team_18_19])
top_teams_09_18
# Out:
# /Users/tom_foolery312/anaconda3/envs/Pythondata/lib/python3.6/site-packages/IPython/core/displayhook.py:271: UserWarning: Output cache limit (currently 1000 entries) hit.
# Flushing oldest 200 entries.
#   'Flushing oldest {cull_count} entries.'.format(sz=sz, cull_count=cull_count))
#                      TEAM   Season   WIN%    PTS   FGM   FGA   3PM   3PA  \
# 4     Cleveland Cavaliers  2009-10  0.744  102.1  37.8  77.9   7.3  19.3
# 3           Chicago Bulls  2010-11  0.756   98.6  37.1  80.3   6.2  17.3
# 3           Chicago Bulls  2011-12  0.758   96.3  37.4  82.8   6.3  16.9
# 13             Miami Heat  2012-13  0.805  102.9  38.4  77.4   8.7  22.1
# 26      San Antonio Spurs  2013-14  0.756  105.4  40.6  83.5   8.5  21.4
# 9   Golden State Warriors  2014-15  0.817  110.0  41.6  87.0  10.8  27.0
# 9   Golden State Warriors  2015-16  0.890  114.9  42.5  87.3  13.1  31.6
# 9   Golden State Warriors  2016-17  0.817  115.9  43.1  87.1  12.0  31.2
# ...

# %%
#top_teams_combined_df = top_teams_09_18[top_teams_09_18["WIN%"].mean()*100]
#top_teams_combined_df

# %%
total_winpercentage2009_19 = top_teams_09_18["WIN%"].mean()*100
total_winpercentage2009_19
# Out:
# 78.68

# %%
total_pts_scored = top_teams_09_18["PTS"].sum()
total_pts_scored
# Out:
# 1076.6

# %%
total_field_goals_made = top_teams_09_18["FGM"].sum()
total_field_goals_made
# Out:
# 400.59999999999997

# %%
total_field_goals_attempted = top_teams_09_18["FGA"].sum()
total_field_goals_attempted
# Out:
# 838.6

# %%
total_three_pointers_attempted = top_teams_09_18["3PA"].sum()
total_three_pointers_attempted
# Out:
# 267.29999999999995

# %%
total_three_pointers_made = top_teams_09_18["3PM"].sum()
total_three_pointers_made
# Out:
# 101.7

# %%
total_freethrows_made = top_teams_09_18["FTM"].sum()
total_freethrows_made
# Out:
# 173.6

# %%
total_freethrows_attempted = top_teams_09_18["FTA"].sum()
total_freethrows_attempted
# Out:
# 228.7

# %%
top_teams_2009_19 = pd.DataFrame({"Win%": [total_winpercentage2009_19], 
                                    "Total Points Scored" : [total_pts_scored], 
                                    "FGA" : [total_field_goals_attempted], 
                                    "FGM" : [total_field_goals_made], 
                                    "3PA" : [total_three_pointers_attempted], 
                                    "3PM" : [total_three_pointers_made], 
                                    "TFA" : [total_freethrows_attempted], 
                                    "TFM" : [total_freethrows_made]})
top_teams_2009_19
# Out:
#     Win%  Total Points Scored    FGA    FGM    3PA    3PM    TFA    TFM
# 0  78.68               1076.6  838.6  400.6  267.3  101.7  228.7  173.6

# %%
bottom_five_teams_WINS_09_10 = bottom_five_teams_09_10["WIN%"].mean()*100
bottom_five_teams_WINS_09_10
# Out:
# 29.020000000000003

# %%
bottom_five_teams_PTS_09_10 = bottom_five_teams_09_10["PTS"].sum()
bottom_five_teams_PTS_09_10
# Out:
# 497.2

# %%
bottom_five_teams_FGM_09_10 = bottom_five_teams_09_10["FGM"].sum()
bottom_five_teams_FGM_09_10
# Out:
# 189.4

# %%
bottom_five_teams_FGA_09_10 = bottom_five_teams_09_10["FGA"].sum()
bottom_five_teams_FGA_09_10
# Out:
# 417.19999999999993

# %%
bottom_five_teams_3PM_09_10 = bottom_five_teams_09_10["3PM"].sum()
bottom_five_teams_3PM_09_10
# Out:
# 28.4

# %%
bottom_five_teams_3PA_09_10 = bottom_five_teams_09_10["3PA"].sum()
bottom_five_teams_3PA_09_10
# Out:
# 81.30000000000001

# %%
bottom_five_teams_FTM_09_10 = bottom_five_teams_09_10["FTM"].sum()
bottom_five_teams_FTM_09_10
# Out:
# 90.1

# %%
bottom_five_teams_FTA_09_10 = bottom_five_teams_09_10["FTA"].sum()
bottom_five_teams_FTA_09_10
# Out:
# 120.4

# %%
bottom_five_teams_09_10 = pd.DataFrame({'WIN%': [bottom_five_teams_WINS_09_10], 
                                        'PTS' : [bottom_five_teams_PTS_09_10],
                                        'FGM' : [bottom_five_teams_FGA_09_10],
                                        'FGA' : [bottom_five_teams_FGM_09_10],
                                        '3PM' : [bottom_five_teams_3PM_09_10],
                                        '3PA' : [bottom_five_teams_3PA_09_10],
                                        'FTM' : [bottom_five_teams_FTM_09_10],
                                        'FTA' : [bottom_five_teams_FTA_09_10]})
bottom_five_teams_09_10
# Out:
#     WIN%    PTS    FGM    FGA   3PM   3PA   FTM    FTA
# 0  29.02  497.2  417.2  189.4  28.4  81.3  90.1  120.4

# %%
bottom_five_teams_WINS_10_11 = bottom_five_teams_10_11["WIN%"].mean()*100
bottom_five_teams_WINS_10_11
# Out:
# 27.32

# %%
bottom_five_teams_PTS_10_11 = bottom_five_teams_10_11["PTS"].sum()
bottom_five_teams_PTS_10_11
# Out:
# 485.5

# %%
bottom_five_teams_FGA_10_11 = bottom_five_teams_10_11["FGA"].sum()
bottom_five_teams_FGA_10_11
# Out:
# 413.6

# %%
bottom_five_teams_FGM_10_11 = bottom_five_teams_10_11["FGM"].sum()
bottom_five_teams_FGM_10_11
# Out:
# 184.5

# %%
bottom_five_teams_3PA_10_11 = bottom_five_teams_10_11["3PA"].sum()
bottom_five_teams_3PA_10_11
# Out:
# 77.8

# %%
bottom_five_teams_3PM_10_11 = bottom_five_teams_10_11["3PM"].sum()
bottom_five_teams_3PM_10_11
# Out:
# 26.0

# %%
bottom_five_teams_FTM_10_11 = bottom_five_teams_10_11["FTM"].mean()*100
bottom_five_teams_FTM_10_11
# Out:
# 1808.0000000000002

# %%
bottom_five_teams_FTA_10_11 = bottom_five_teams_10_11["FTA"].mean()*100
bottom_five_teams_FTA_10_11
# Out:
# 2418.0

# %%
bottom_five_teams_10_11 = pd.DataFrame({'WIN%': [bottom_five_teams_WINS_10_11], 
                                        'PTS' : [bottom_five_teams_PTS_10_11],
                                        'FGM' : [bottom_five_teams_FGA_10_11],
                                        'FGA' : [bottom_five_teams_FGM_10_11],
                                        '3PM' : [bottom_five_teams_3PM_10_11],
                                        '3PA' : [bottom_five_teams_3PA_10_11],
                                        'FTM' : [bottom_five_teams_FTM_10_11],
                                        'FTA' : [bottom_five_teams_FTA_10_11]})
bottom_five_teams_10_11
# Out:
#     WIN%    PTS    FGM    FGA   3PM   3PA     FTM     FTA
# 0  27.32  485.5  413.6  184.5  26.0  77.8  1808.0  2418.0

# %%
bottom_five_teams_WINS_11_12 = bottom_five_teams_11_12["WIN%"].mean()*100
bottom_five_teams_WINS_11_12
# Out:
# 32.1

# %%
bottom_five_teams_PTS_11_12 = bottom_five_teams_11_12["PTS"].sum()
bottom_five_teams_PTS_11_12
# Out:
# 468.1

# %%
bottom_five_teams_FGA_11_12 = bottom_five_teams_11_12["FGA"].sum()
bottom_five_teams_FGA_11_12
# Out:
# 408.59999999999997

# %%
bottom_five_teams_FGM_11_12 = bottom_five_teams_11_12["FGM"].sum()
bottom_five_teams_FGM_11_12
# Out:
# 177.7

# %%
bottom_five_teams_3PM_11_12 = bottom_five_teams_11_12["3PM"].sum()
bottom_five_teams_3PM_11_12
# Out:
# 29.7

# %%
bottom_five_teams_3PA_11_12 = bottom_five_teams_11_12["3PA"].sum()
bottom_five_teams_3PA_11_12
# Out:
# 89.49999999999999

# %%
bottom_five_teams_FTM_11_12 = bottom_five_teams_11_12["FTM"].sum()
bottom_five_teams_FTM_11_12
# Out:
# 83.1

# %%
bottom_five_teams_FTA_11_12 = bottom_five_teams_11_12["FTA"].sum()
bottom_five_teams_FTA_11_12
# Out:
# 112.0

# %%
bottom_five_teams_11_12 = pd.DataFrame({'WIN%': [bottom_five_teams_WINS_11_12], 
                                        'PTS' : [bottom_five_teams_PTS_11_12],
                                        'FGM' : [bottom_five_teams_FGA_11_12],
                                        'FGA' : [bottom_five_teams_FGM_11_12],
                                        '3PM' : [bottom_five_teams_3PM_11_12],
                                        '3PA' : [bottom_five_teams_3PA_11_12],
                                        'FTM' : [bottom_five_teams_FTM_11_12],
                                        'FTA' : [bottom_five_teams_FTA_11_12]})
bottom_five_teams_11_12
# Out:
#    WIN%    PTS    FGM    FGA   3PM   3PA   FTM    FTA
# 0  32.1  468.1  408.6  177.7  29.7  89.5  83.1  112.0

# %%
bottom_five_teams_WINS_12_13 = bottom_five_teams_12_13["WIN%"].mean()*100
bottom_five_teams_WINS_12_13
# Out:
# 30.48

# %%
bottom_five_teams_PTS_12_13 = bottom_five_teams_12_13["PTS"].sum()
bottom_five_teams_PTS_12_13
# Out:
# 479.4

# %%
bottom_five_teams_FGA_12_13 = bottom_five_teams_12_13["FGA"].sum()
bottom_five_teams_FGA_12_13
# Out:
# 414.30000000000007

# %%
bottom_five_teams_FGM_12_13 = bottom_five_teams_12_13["FGM"].sum()
bottom_five_teams_FGM_12_13
# Out:
# 181.79999999999998

# %%
bottom_five_teams_3PM_12_13 = bottom_five_teams_12_13["3PM"].sum()
bottom_five_teams_3PM_12_13
# Out:
# 32.2

# %%
bottom_five_teams_3PA_12_13 = bottom_five_teams_12_13["3PA"].sum()
bottom_five_teams_3PA_12_13
# Out:
# 92.6

# %%
bottom_five_teams_FTM_12_13 = bottom_five_teams_12_13["FTM"].sum()
bottom_five_teams_FTM_12_13
# Out:
# 83.4

# %%
bottom_five_teams_FTA_12_13 = bottom_five_teams_12_13["FTA"].sum()
bottom_five_teams_FTA_12_13
# Out:
# 109.9

# %%
bottom_five_teams_12_13 = pd.DataFrame({'WIN%': [bottom_five_teams_WINS_12_13], 
                                        'PTS' : [bottom_five_teams_PTS_12_13],
                                        'FGM' : [bottom_five_teams_FGA_12_13],
                                        'FGA' : [bottom_five_teams_FGM_12_13],
                                        '3PM' : [bottom_five_teams_3PM_12_13],
                                        '3PA' : [bottom_five_teams_3PA_12_13],
                                        'FTM' : [bottom_five_teams_FTM_12_13],
                                        'FTA' : [bottom_five_teams_FTA_12_13]})
bottom_five_teams_12_13
# Out:
#     WIN%    PTS    FGM    FGA   3PM   3PA   FTM    FTA
# 0  30.48  479.4  414.3  181.8  32.2  92.6  83.4  109.9

# %%
bottom_five_teams_WINS_13_14 = bottom_five_teams_13_14["WIN%"].mean()*100
bottom_five_teams_WINS_13_14
# Out:
# 29.020000000000003

# %%
bottom_five_teams_PTS_13_14 = bottom_five_teams_13_14["PTS"].sum()
bottom_five_teams_PTS_13_14
# Out:
# 490.2

# %%
bottom_five_teams_FGA_13_14 = bottom_five_teams_13_14["FGA"].sum()
bottom_five_teams_FGA_13_14
# Out:
# 420.0

# %%
bottom_five_teams_FGM_13_14 = bottom_five_teams_13_14["FGM"].sum()
bottom_five_teams_FGM_13_14
# Out:
# 185.6

# %%
bottom_five_teams_3PM_13_14 = bottom_five_teams_13_14["3PM"].sum()
bottom_five_teams_3PM_13_14
# Out:
# 36.9

# %%
bottom_five_teams_3PA_13_14 = bottom_five_teams_13_14["3PA"].sum()
bottom_five_teams_3PA_13_14
# Out:
# 107.10000000000001

# %%
bottom_five_teams_FTM_13_14 = bottom_five_teams_13_14["FTM"].sum()
bottom_five_teams_FTM_13_14
# Out:
# 82.1

# %%
bottom_five_teams_FTA_13_14 = bottom_five_teams_13_14["FTA"].sum()
bottom_five_teams_FTA_13_14
# Out:
# 109.5

# %%
bottom_five_teams_13_14 = pd.DataFrame({'WIN%': [bottom_five_teams_WINS_13_14], 
                                        'PTS' : [bottom_five_teams_PTS_13_14],
                                        'FGM' : [bottom_five_teams_FGA_13_14],
                                        'FGA' : [bottom_five_teams_FGM_13_14],
                                        '3PM' : [bottom_five_teams_3PM_13_14],
                                        '3PA' : [bottom_five_teams_3PA_13_14],
                                        'FTM' : [bottom_five_teams_FTM_13_14],
                                        'FTA' : [bottom_five_teams_FTA_13_14]})
bottom_five_teams_13_14
# Out:
#     WIN%    PTS    FGM    FGA   3PM    3PA   FTM    FTA
# 0  29.02  490.2  420.0  185.6  36.9  107.1  82.1  109.5

# %%
bottom_five_teams_WINS_14_15 = bottom_five_teams_14_15["WIN%"].mean()*100
bottom_five_teams_WINS_14_15
# Out:
# 26.840000000000003

# %%
bottom_five_teams_PTS_14_15 = bottom_five_teams_14_15["PTS"].sum()
bottom_five_teams_PTS_14_15
# Out:
# 479.4

# %%
bottom_five_teams_FGA_14_15 = bottom_five_teams_14_15["FGA"].sum()
bottom_five_teams_FGA_14_15
# Out:
# 413.7

# %%
bottom_five_teams_FGM_14_15 = bottom_five_teams_14_15["FGM"].sum()
bottom_five_teams_FGM_14_15
# Out:
# 180.20000000000002

# %%
bottom_five_teams_3PM_14_15 = bottom_five_teams_14_15["3PM"].sum()
bottom_five_teams_3PM_14_15
# Out:
# 34.099999999999994

# %%
bottom_five_teams_3PA_14_15 = bottom_five_teams_14_15["3PA"].sum()
bottom_five_teams_3PA_14_15
# Out:
# 100.9

# %%
bottom_five_teams_FTM_14_15 = bottom_five_teams_14_15["FTM"].sum()
bottom_five_teams_FTM_14_15
# Out:
# 84.60000000000001

# %%
bottom_five_teams_FTA_14_15 = bottom_five_teams_14_15["FTA"].sum()
bottom_five_teams_FTA_14_15
# Out:
# 115.0

# %%
bottom_five_teams_14_15 = pd.DataFrame({'WIN%': [bottom_five_teams_WINS_14_15], 
                                        'PTS' : [bottom_five_teams_PTS_14_15],
                                        'FGM' : [bottom_five_teams_FGA_14_15],
                                        'FGA' : [bottom_five_teams_FGM_14_15],
                                        '3PM' : [bottom_five_teams_3PM_14_15],
                                        '3PA' : [bottom_five_teams_3PA_14_15],
                                        'FTM' : [bottom_five_teams_FTM_14_15],
                                        'FTA' : [bottom_five_teams_FTA_14_15]})
bottom_five_teams_14_15
# Out:
#     WIN%    PTS    FGM    FGA   3PM    3PA   FTM    FTA
# 0  26.84  479.4  413.7  180.2  34.1  100.9  84.6  115.0

# %%
bottom_five_teams_WINS_15_16 = bottom_five_teams_15_16["WIN%"].mean()*100
bottom_five_teams_WINS_15_16
# Out:
# 29.26

# %%
bottom_five_teams_PTS_15_16 = bottom_five_teams_15_16["PTS"].sum()
bottom_five_teams_PTS_15_16
# Out:
# 501.90000000000003

# %%
bottom_five_teams_FGA_15_16 = bottom_five_teams_15_16["FGA"].sum()
bottom_five_teams_FGA_15_16
# Out:
# 422.0

# %%
bottom_five_teams_FGM_15_16 = bottom_five_teams_15_16["FGM"].sum()
bottom_five_teams_FGM_15_16
# Out:
# 186.70000000000002

# %%
bottom_five_teams_3PM_15_16 = bottom_five_teams_15_16["3PM"].sum()
bottom_five_teams_3PM_15_16
# Out:
# 37.4

# %%
bottom_five_teams_3PA_15_16 = bottom_five_teams_15_16["3PA"].sum()
bottom_five_teams_3PA_15_16
# Out:
# 109.0

# %%
bottom_five_teams_FTM_15_16 = bottom_five_teams_15_16["FTM"].sum()
bottom_five_teams_FTM_15_16
# Out:
# 91.2

# %%
bottom_five_teams_FTA_15_16 = bottom_five_teams_15_16["FTA"].sum()
bottom_five_teams_FTA_15_16
# Out:
# 117.80000000000001

# %%
bottom_five_teams_15_16 = pd.DataFrame({'WIN%': [bottom_five_teams_WINS_15_16], 
                                        'PTS' : [bottom_five_teams_PTS_15_16],
                                        'FGM' : [bottom_five_teams_FGA_15_16],
                                        'FGA' : [bottom_five_teams_FGM_15_16],
                                        '3PM' : [bottom_five_teams_3PM_15_16],
                                        '3PA' : [bottom_five_teams_3PA_15_16],
                                        'FTM' : [bottom_five_teams_FTM_15_16],
                                        'FTA' : [bottom_five_teams_FTA_15_16]})
bottom_five_teams_15_16
# Out:
#     WIN%    PTS    FGM    FGA   3PM    3PA   FTM    FTA
# 0  29.26  501.9  422.0  186.7  37.4  109.0  91.2  117.8

# %%
bottom_five_teams_WINS_16_17 = bottom_five_teams_16_17["WIN%"].mean()*100
bottom_five_teams_WINS_16_17
# Out:
# 33.66

# %%
bottom_five_teams_PTS_16_17 = bottom_five_teams_16_17["PTS"].sum()
bottom_five_teams_PTS_16_17
# Out:
# 520.1

# %%
bottom_five_teams_FGA_16_17 = bottom_five_teams_16_17["FGA"].sum()
bottom_five_teams_FGA_16_17
# Out:
# 436.70000000000005

# %%
bottom_five_teams_FGM_16_17 = bottom_five_teams_16_17["FGM"].sum()
bottom_five_teams_FGM_16_17
# Out:
# 194.8

# %%
bottom_five_teams_3PM_16_17 = bottom_five_teams_16_17["3PM"].sum()
bottom_five_teams_3PM_16_17
# Out:
# 43.6

# %%
bottom_five_teams_3PA_16_17 = bottom_five_teams_15_16["3PA"].sum()
bottom_five_teams_3PA_16_17
# Out:
# 109.0

# %%
bottom_five_teams_FTM_16_17 = bottom_five_teams_16_17["FTM"].sum()
bottom_five_teams_FTM_16_17
# Out:
# 87.0

# %%
bottom_five_teams_FTA_16_17 = bottom_five_teams_16_17["FTA"].sum()
bottom_five_teams_FTA_16_17
# Out:
# 113.39999999999999

# %%
bottom_five_teams_16_17 = pd.DataFrame({'WIN%': [bottom_five_teams_WINS_16_17], 
                                        'PTS' : [bottom_five_teams_PTS_16_17],
                                        'FGM' : [bottom_five_teams_FGA_16_17],
                                        'FGA' : [bottom_five_teams_FGM_16_17],
                                        '3PM' : [bottom_five_teams_3PM_16_17],
                                        '3PA' : [bottom_five_teams_3PA_16_17],
                                        'FTM' : [bottom_five_teams_FTM_16_17],
                                        'FTA' : [bottom_five_teams_FTA_16_17]})
bottom_five_teams_16_17
# Out:
#     WIN%    PTS    FGM    FGA   3PM    3PA   FTM    FTA
# 0  33.66  520.1  436.7  194.8  43.6  109.0  87.0  113.4

# %%
bottom_five_teams_WINS_17_18 = bottom_five_teams_17_18["WIN%"].mean()*100
bottom_five_teams_WINS_17_18
# Out:
# 29.759999999999998

# %%
bottom_five_teams_PTS_17_18 = bottom_five_teams_17_18["PTS"].sum()
bottom_five_teams_PTS_17_18
# Out:
# 511.3

# %%
bottom_five_teams_FGA_17_18 = bottom_five_teams_17_18["FGA"].sum()
bottom_five_teams_FGA_17_18
# Out:
# 428.90000000000003

# %%
bottom_five_teams_FGM_17_18 = bottom_five_teams_17_18["FGM"].sum()
bottom_five_teams_FGM_17_18
# Out:
# 190.5

# %%
bottom_five_teams_3PM_17_18 = bottom_five_teams_17_18["3PM"].sum()
bottom_five_teams_3PM_17_18
# Out:
# 53.5

# %%
bottom_five_teams_3PA_17_18 = bottom_five_teams_17_18["3PA"].sum()
bottom_five_teams_3PA_17_18
# Out:
# 150.4

# %%
bottom_five_teams_FTM_17_18 = bottom_five_teams_17_18["FTM"].sum()
bottom_five_teams_FTM_17_18
# Out:
# 76.69999999999999

# %%
bottom_five_teams_FTA_17_18 = bottom_five_teams_17_18["FTA"].sum()
bottom_five_teams_FTA_17_18
# Out:
# 99.70000000000002

# %%
bottom_five_teams_17_18 = pd.DataFrame({'WIN%': [bottom_five_teams_WINS_17_18], 
                                        'PTS' : [bottom_five_teams_PTS_17_18],
                                        'FGM' : [bottom_five_teams_FGA_17_18],
                                        'FGA' : [bottom_five_teams_FGM_17_18],
                                        '3PM' : [bottom_five_teams_3PM_17_18],
                                        '3PA' : [bottom_five_teams_3PA_17_18],
                                        'FTM' : [bottom_five_teams_FTM_17_18],
                                        'FTA' : [bottom_five_teams_FTA_17_18]})
bottom_five_teams_17_18
# Out:
#     WIN%    PTS    FGM    FGA   3PM    3PA   FTM   FTA
# 0  29.76  511.3  428.9  190.5  53.5  150.4  76.7  99.7

# %%
bottom_five_teams_WINS_18_19 = bottom_five_teams_18_19["WIN%"].mean()*100
bottom_five_teams_WINS_18_19
# Out:
# 29.520000000000003

# %%
bottom_five_teams_PTS_18_19 = bottom_five_teams_18_19["PTS"].sum()
bottom_five_teams_PTS_18_19
# Out:
# 544.2

# %%
bottom_five_teams_FGA_18_19 = bottom_five_teams_18_19["FGA"].sum()
bottom_five_teams_FGA_18_19
# Out:
# 444.79999999999995

# %%
bottom_five_teams_FGM_18_19 = bottom_five_teams_18_19["FGM"].sum()
bottom_five_teams_FGM_18_19
# Out:
# 202.3

# %%
bottom_five_teams_3PM_18_19 = bottom_five_teams_18_19["3PM"].sum()
bottom_five_teams_3PM_18_19
# Out:
# 53.3

# %%
bottom_five_teams_3PA_18_19 = bottom_five_teams_18_19["3PA"].sum()
bottom_five_teams_3PA_18_19
# Out:
# 154.6

# %%
bottom_five_teams_FTM_18_19 = bottom_five_teams_18_19["FTM"].sum()
bottom_five_teams_FTM_18_19
# Out:
# 86.20000000000002

# %%
bottom_five_teams_FTA_18_19 = bottom_five_teams_18_19["FTA"].sum()
bottom_five_teams_FTA_18_19
# Out:
# 111.4

# %%
bottom_five_teams_18_19 = pd.DataFrame({'WIN%': [bottom_five_teams_WINS_18_19], 
                                        'PTS' : [bottom_five_teams_PTS_18_19],
                                        'FGM' : [bottom_five_teams_FGA_18_19],
                                        'FGA' : [bottom_five_teams_FGM_18_19],
                                        '3PM' : [bottom_five_teams_3PM_18_19],
                                        '3PA' : [bottom_five_teams_3PA_18_19],
                                        'FTM' : [bottom_five_teams_FTM_18_19],
                                        'FTA' : [bottom_five_teams_FTA_18_19]})
bottom_five_teams_18_19
# Out:
#     WIN%    PTS    FGM    FGA   3PM    3PA   FTM    FTA
# 0  29.52  544.2  444.8  202.3  53.3  154.6  86.2  111.4

# %%
average_of_worst_teams_per_season = pd.concat([bottom_five_teams_09_10, bottom_five_teams_10_11, bottom_five_teams_11_12, bottom_five_teams_12_13, bottom_five_teams_13_14, bottom_five_teams_14_15, bottom_five_teams_15_16, bottom_five_teams_16_17, bottom_five_teams_17_18, bottom_five_teams_18_19])
average_of_worst_teams_per_season
# Out:
#     WIN%    PTS    FGM    FGA   3PM    3PA     FTM     FTA
# 0  29.02  497.2  417.2  189.4  28.4   81.3    90.1   120.4
# 0  27.32  485.5  413.6  184.5  26.0   77.8  1808.0  2418.0
# 0  32.10  468.1  408.6  177.7  29.7   89.5    83.1   112.0
# 0  30.48  479.4  414.3  181.8  32.2   92.6    83.4   109.9
# 0  29.02  490.2  420.0  185.6  36.9  107.1    82.1   109.5
# 0  26.84  479.4  413.7  180.2  34.1  100.9    84.6   115.0
# 0  29.26  501.9  422.0  186.7  37.4  109.0    91.2   117.8
# 0  33.66  520.1  436.7  194.8  43.6  109.0    87.0   113.4
# 0  29.76  511.3  428.9  190.5  53.5  150.4    76.7    99.7
# 0  29.52  544.2  444.8  202.3  53.3  154.6    86.2   111.4
